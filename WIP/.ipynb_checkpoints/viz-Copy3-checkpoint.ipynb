# %%
from ipywidgets import interact

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pylab as ply

# %%
import networkx as nx

# %%
G=nx.Graph()
# Add nodes and edges
G.add_edge("Node1", "Node2")
interact(nx.draw(G, with_labels = True))

# %%
def random_lobster(n, m, k, p):
    return nx.random_lobster(n, p, p / m)

def powerlaw_cluster(n, m, k, p):
    return nx.powerlaw_cluster_graph(n, m, p)

def erdos_renyi(n, m, k, p):
    return nx.erdos_renyi_graph(n, p)

def newman_watts_strogatz(n, m, k, p):
    return nx.newman_watts_strogatz_graph(n, k, p)

def plot_random_graph(n, m, k, p, generator):
    g = generator(n, m, k, p)
    nx.draw(g)
    plt.show()

# %%
interact(plot_random_graph, n=(2,30), m=(1,10), k=(1,10), p=(0.0, 1.0, 0.001),
         generator={
             'lobster': random_lobster,
             'power law': powerlaw_cluster,
             'Newman-Watts-Strogatz': newman_watts_strogatz,
             u'Erdős-Rényi': erdos_renyi,
         });
# Out:
# interactive(children=(IntSlider(value=16, description='n', max=30, min=2), IntSlider(value=5, description='m', max=10, min=1), IntSlider(value=5, description='k', max=10, min=1), FloatSlider(value=0.5, description='p', max=1.0, step=0.001), Dropdown(description='generator', options={'lobster': <function random_lobster at 0x109c42ae8>, 'power law': <function powerlaw_cluster at 0x109c42d08>, 'Newman-Watts-Strogatz': <function newman_watts_strogatz at 0x109c42e18>, 'Erdős-Rényi': <function erdos_renyi at 0x109c42d90>}, value=<function random_lobster at 0x109c42ae8>), Output()), _dom_classes=('widget-interact',))

# %%
def newman_watts_strogatz(n, m, k, p):
    return nx.newman_watts_strogatz_graph(n, k, p)

# %%
g = generator(n, m, k, p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-21558d7e704a> in <module>()
# ----> 1 g = generator(n, m, k, p)
#       2 nx.draw(g)
#       3 plt.show()
#
# NameError: name 'generator' is not defined

# %%
def plot_random_graph(n, m, k, p, generator):
    g = generator(n, m, k, p)
    nx.draw(g)
    plt.show()

# %%
# gen = newman_watts_strogatz(20,1,10, 0.001)
interact(plot_random_graph(20,1,10, 0.001,newman_watts_strogatz))
# nx.draw(gen)
# plt.show()

# %%
plot_random_graph()
# Out:
#   File "<ipython-input-15-c66286de09e6>", line 1
#     plot_random_graph, n=(2,30), m=(1,10), k=(1,10), p=(0.0, 1.0, 0.001),'Newman-Watts-Strogatz': newman_watts_strogatz,)
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
#connect to graph database
my_graph = Graph('http://localhost:7474/')

# %%
ingredient_query="""MATCH (i:ingredient) return i.name limit 100"""
ingredient_list = list(my_graph.run(ingredient_query).data())
options = {"component": "name", "ingredient": "name"}
# options = {"component": "name", "ingredient": "name"}

# %%
@interact(ingredient = ingredient_list)
def plot(ingredient):
    _ = neo4jupyter.draw(my_graph, options)
# Out:
# interactive(children=(Dropdown(description='ingredient', options=({'i.name': 'onion'}, {'i.name': 'milk'}, {'i.name': 'bulgur'}, {'i.name': 'tomato'}, {'i.name': 'black beans'}, {'i.name': 'quinoa'}, {'i.name': 'coconut milk'}, {'i.name': 'scallion'}, {'i.name': 'water'}, {'i.name': 'pear'}, {'i.name': 'banana'}, {'i.name': 'rice'}, {'i.name': 'beef'}, {'i.name': 'red peppers'}, {'i.name': 'celery'}, {'i.name': 'lemon'}, {'i.name': 'red onions'}, {'i.name': 'white vinegar'}, {'i.name': 'carrot'}, {'i.name': 'tahini'}, {'i.name': 'bell pepper'}, {'i.name': 'bay leaf'}, {'i.name': 'cumin'}, {'i.name': 'parsley'}, {'i.name': 'macaroni'}, {'i.name': 'cheese'}, {'i.name': 'garlic'}, {'i.name': 'sweet potatoes'}, {'i.name': 'sweet paprika'}, {'i.name': 'cayenne pepper'}), value={'i.name': 'onion'}), Output()), _dom_classes=('widget-interact',))

# %%
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]

# Simple mouse click function to store coordinates
def onclick(event):
    global ix, iy
    ix, iy = event.xdata, event.ydata

    # print 'x = %d, y = %d'%(
    #     ix, iy)

    # assign global variable to access outside of function
    global coords
    coords.append((ix, iy))

    # Disconnect after 2 clicks
    if len(coords) == 2:
        fig.canvas.mpl_disconnect(cid)
        plt.close(1)
    return


x = np.arange(-10,10)
y = x**2

fig = plt.figure(1)
# ax = fig.add_subplot(111)
# ax.plot(x,y)

coords = []
# Call click func
cid = fig.canvas.mpl_connect('button_press_event', onclick)

# plt.show()
dir(fig)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
# ['_Figure__remove_ax',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alpha',
#  '_animated',
#  '_axobservers',
#  '_axstack',
#  '_cachedRenderer',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_dpi',
#  '_gci',
#  '_get_axes',
#  '_get_dpi',
#  '_gid',
#  '_hold',
#  '_label',
#  '_make_key',
#  '_mouseover',
#  '_oid',
#  '_path_effects',
#  '_picker',
#  '_prop_order',
#  '_propobservers',
#  '_rasterized',
#  '_remove_method',
#  '_repr_html_',
#  '_set_artist_props',
#  '_set_dpi',
#  '_set_gc_clip',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_sticky_edges',
#  '_suptitle',
#  '_tight',
#  '_tight_parameters',
#  '_transform',
#  '_transformSet',
#  '_url',
#  '_visible',
#  'add_axes',
#  'add_axobserver',
#  'add_callback',
#  'add_subplot',
#  'aname',
#  'artists',
#  'autofmt_xdate',
#  'axes',
#  'bbox',
#  'bbox_inches',
#  'callbacks',
#  'canvas',
#  'clear',
#  'clf',
#  'clipbox',
#  'colorbar',
#  'contains',
#  'convert_xunits',
#  'convert_yunits',
#  'delaxes',
#  'dpi',
#  'dpi_scale_trans',
#  'draw',
#  'draw_artist',
#  'eventson',
#  'figimage',
#  'figure',
#  'figurePatch',
#  'findobj',
#  'format_cursor_data',
#  'frameon',
#  'gca',
#  'get_agg_filter',
#  'get_alpha',
#  'get_animated',
#  'get_axes',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_contains',
#  'get_cursor_data',
#  'get_default_bbox_extra_artists',
#  'get_dpi',
#  'get_edgecolor',
#  'get_facecolor',
#  'get_figheight',
#  'get_figure',
#  'get_figwidth',
#  'get_frameon',
#  'get_gid',
#  'get_label',
#  'get_path_effects',
#  'get_picker',
#  'get_rasterized',
#  'get_size_inches',
#  'get_sketch_params',
#  'get_snap',
#  'get_tight_layout',
#  'get_tightbbox',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_zorder',
#  'ginput',
#  'have_units',
#  'hitlist',
#  'hold',
#  'images',
#  'is_figure_set',
#  'is_transform_set',
#  'legend',
#  'legends',
#  'lines',
#  'mouseover',
#  'number',
#  'patch',
#  'patches',
#  'pchanged',
#  'pick',
#  'pickable',
#  'properties',
#  'remove',
#  'remove_callback',
#  'savefig',
#  'sca',
#  'set',
#  'set_agg_filter',
#  'set_alpha',
#  'set_animated',
#  'set_canvas',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_contains',
#  'set_dpi',
#  'set_edgecolor',
#  'set_facecolor',
#  'set_figheight',
#  'set_figure',
#  'set_figwidth',
#  'set_frameon',
#  'set_gid',
#  'set_label',
#  'set_path_effects',
#  'set_picker',
#  'set_rasterized',
#  'set_size_inches',
#  'set_sketch_params',
#  'set_snap',
#  'set_tight_layout',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_zorder',
#  'show',
#  'stale',
#  'stale_callback',
#  'sticky_edges',
#  'subplotpars',
#  'subplots',
#  'subplots_adjust',
#  'suppressComposite',
#  'suptitle',
#  'text',
#  'texts',
#  'tight_layout',
#  'transFigure',
#  'update',
#  'update_from',
#  'waitforbuttonpress',
#  'zorder']

# %%
fig = neo4jupyter.draw(my_graph, options)
# dir(fig)
fig
# Out:
# <div id="ad19cd5b-14ef-46b0-b890-9d3eb0b7d445" style="height: 400px;"></div>
#
# <script type="text/javascript">
#
#     var nodes = [{"id": 1, "label": "onion", "group": "ingredient", "title": "{'name': 'onion'}"}, {"id": 135, "label": "bulgur", "group": "ingredient", "title": "{'name': 'bulgur'}"}, {"id": 320, "label": "parsley", "group": "ingredient", "title": "{'name': 'parsley'}"}, {"id": 299, "label": "puerto rican style black beans", "group": "component", "title": "{'name': 'puerto rican style black beans'}"}, {"id": 138, "label": "black beans", "group": "ingredient", "title": "{'name': 'black beans'}"}, {"id": 298, "label": "sofrito", "group": "component", "title": "{'name': 'sofrito'}"}, {"id": 301, "label": "bay leaf", "group": "ingredient", "title": "{'name': 'bay leaf'}"}, {"id": 103, "label": "rice and beans", "group": "component", "title": "{'name': 'rice and beans'}"}, {"id": 0, "label": "sauteed onion and garlic", "group": "component", "title": "{'name': 'sauteed onion and garlic'}"}, {"id": 209, "label": "scallion", "group": "ingredient", "title": "{'name': 'scallion'}"}, {"id": 266, "label": "red onions", "group": "ingredient", "title": "{'name': 'red onions'}"}, {"id": 233, "label": "rice", "group": "ingredient", "title": "{'name': 'rice'}"}, {"id": 342, "label": "sweet potatoes", "group": "ingredient", "title": "{'name': 'sweet potatoes'}"}, {"id": 300, "label": "bell pepper", "group": "ingredient", "title": "{'name': 'bell pepper'}"}, {"id": 137, "label": "tomato", "group": "ingredient", "title": "{'name': 'tomato'}"}, {"id": 314, "label": "cumin", "group": "ingredient", "title": "{'name': 'cumin'}"}, {"id": 190, "label": "coconut milk", "group": "ingredient", "title": "{'name': 'coconut milk'}"}, {"id": 322, "label": "macaroni", "group": "ingredient", "title": "{'name': 'macaroni'}"}, {"id": 296, "label": "chicken marinade", "group": "component", "title": "{'name': 'chicken marinade'}"}, {"id": 333, "label": "garlic", "group": "ingredient", "title": "{'name': 'garlic'}"}, {"id": 344, "label": "cayenne pepper", "group": "ingredient", "title": "{'name': 'cayenne pepper'}"}, {"id": 264, "label": "lemon", "group": "ingredient", "title": "{'name': 'lemon'}"}, {"id": 265, "label": "black bean salad", "group": "component", "title": "{'name': 'black bean salad'}"}, {"id": 268, "label": "carrot", "group": "ingredient", "title": "{'name': 'carrot'}"}, {"id": 267, "label": "white vinegar", "group": "ingredient", "title": "{'name': 'white vinegar'}"}, {"id": 321, "label": "macaroni and cheese", "group": "component", "title": "{'name': 'macaroni and cheese'}"}, {"id": 6, "label": "milk", "group": "ingredient", "title": "{'name': 'milk'}"}, {"id": 323, "label": "cheese", "group": "ingredient", "title": "{'name': 'cheese'}"}, {"id": 272, "label": "beef stir-fry", "group": "component", "title": "{'name': 'beef stir-fry'}"}, {"id": 238, "label": "celery", "group": "ingredient", "title": "{'name': 'celery'}"}, {"id": 237, "label": "red peppers", "group": "ingredient", "title": "{'name': 'red peppers'}"}, {"id": 236, "label": "beef", "group": "ingredient", "title": "{'name': 'beef'}"}, {"id": 330, "label": "tabouleh", "group": "component", "title": "{'name': 'tabouleh'}"}, {"id": 255, "label": "salmon", "group": "component", "title": "{'name': 'salmon'}"}, {"id": 232, "label": "coconut rice", "group": "component", "title": "{'name': 'coconut rice'}"}, {"id": 210, "label": "water", "group": "ingredient", "title": "{'name': 'water'}"}, {"id": 188, "label": "quinoa", "group": "ingredient", "title": "{'name': 'quinoa'}"}, {"id": 297, "label": "tahini", "group": "ingredient", "title": "{'name': 'tahini'}"}, {"id": 231, "label": "banana", "group": "ingredient", "title": "{'name': 'banana'}"}, {"id": 341, "label": "spicy and sweet sweet potato cubes", "group": "component", "title": "{'name': 'spicy and sweet sweet potato cubes'}"}, {"id": 343, "label": "sweet paprika", "group": "ingredient", "title": "{'name': 'sweet paprika'}"}, {"id": 4, "label": "", "group": "meal", "title": "{'name': 'meal1'}"}, {"id": 5, "label": "roast chicken", "group": " ...
#     var edges = [{"from": 299, "to": 138, "label": "includes"}, {"from": 299, "to": 298, "label": "includes"}, {"from": 103, "to": 138, "label": "includes"}, {"from": 103, "to": 0, "label": "includes"}, {"from": 296, "to": 333, "label": "includes"}, {"from": 265, "to": 300, "label": "includes"}, {"from": 265, "to": 268, "label": "includes"}, {"from": 265, "to": 137, "label": "includes"}, {"from": 265, "to": 333, "label": "includes"}, {"from": 265, "to": 267, "label": "includes"}, {"from": 265, "to": 266, "label": "includes"}, {"from": 265, "to": 138, "label": "includes"}, {"from": 321, "to": 6, "label": "includes"}, {"from": 321, "to": 323, "label": "includes"}, {"from": 321, "to": 0, "label": "includes"}, {"from": 321, "to": 322, "label": "includes"}, {"from": 272, "to": 238, "label": "includes"}, {"from": 272, "to": 237, "label": "includes"}, {"from": 272, "to": 333, "label": "includes"}, {"from": 272, "to": 236, "label": "includes"}, {"from": 330, "to": 137, "label": "includes"}, {"from": 330, "to": 135, "label": "includes"}, {"from": 330, "to": 320, "label": "includes"}, {"from": 330, "to": 333, "label": "includes"}, {"from": 255, "to": 333, "label": "includes"}, {"from": 255, "to": 264, "label": "includes"}, {"from": 232, "to": 209, "label": "includes"}, {"from": 232, "to": 190, "label": "includes"}, {"from": 232, "to": 233, "label": "includes"}, {"from": 298, "to": 314, "label": "includes"}, {"from": 298, "to": 301, "label": "includes"}, {"from": 298, "to": 1, "label": "includes"}, {"from": 298, "to": 333, "label": "includes"}, {"from": 298, "to": 300, "label": "includes"}, {"from": 341, "to": 344, "label": "includes"}, {"from": 341, "to": 343, "label": "includes"}, {"from": 341, "to": 333, "label": "includes"}, {"from": 341, "to": 342, "label": "includes"}, {"from": 0, "to": 333, "label": "includes"}, {"from": 0, "to": 1, "label": "includes"}, {"from": 4, "to": 5, "label": "has"}, {"from": 295, "to": 297, "label": "includes"}, {"from": 295, "to": 333, "label": "includes"}, {"from": 340, "to": 341, "label": "includes"}, {"from": 214, "to": 264, "label": "includes"}, {"from": 214, "to": 228, "label": "includes"}, {"from": 5, "to": 296, "label": "includes"}, {"from": 189, "to": 210, "label": "includes"}, {"from": 189, "to": 333, "label": "includes"}, {"from": 189, "to": 209, "label": "includes"}, {"from": 189, "to": 190, "label": "includes"}, {"from": 189, "to": 188, "label": "includes"}, {"from": 230, "to": 231, "label": "includes"}];
#
#     var container = document.getElementById("ad19cd5b-14ef-46b0-b890-9d3eb0b7d445");
#
#     var data = {
#         nodes: nodes,
#         edges: edges
#     };
#
#     var options = {
#     nodes: {
#         shape: 'dot',
#         size: 25,
#         font: {
#             size: 14
#         }
#     },
#     edges: {
#         font: {
#             size: 14,
#             align: 'middle'
#         },
#         color: 'gray',
#         arrows: {
#             to: {
#                 enabled: true,
#                 scaleFactor: 0.5
#             }
#         },
#         smooth: {
#             enabled: false
#         }
#     },
#     physics: {
#         enabled: true
#         }
#     };
#
#     var network = new vis.Network(container, data, options);
#
# </script>

# %%
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d71ed1ad3d2b> in <module>()
# ----> 1 fig.url()
#
# TypeError: 'NoneType' object is not callable

# %%
cords = []
def onclick(event):
    global ix, iy
    ix, iy = event.xdata, event.ydata

    # print 'x = %d, y = %d'%(
    #     ix, iy)

    # assign global variable to access outside of function
    global coords
    coords.append((ix, iy))

# %%
H

# %%
my_graph
# Out:
# <Graph uri='http://localhost:7474/db/data/'>

# %%
import networkx as nx
# %load_ext cypher
# %matplotlib inline

results = %cypher MATCH p = ()-[]-() RETURN p

g = results.get_graph()

nx.draw(g)
# Out:
# The cypher extension is already loaded. To reload it, use:
#   %reload_ext cypher
# 106 rows affected.

# %%
import networkx as nx
from matplotlib import pylab as pl
H = nx.karate_club_graph()
pos = nx.spring_layout(H)  #setting the positions with respect to G, not k.

# H = nx.karate_club_graph()
# pos = nx.spring_layout(my_graph)  #setting the positions with respect to G, not k.


pl.figure()
nx.draw_networkx(H)
# nx.draw_networkx(k, pos=pos)
pl.show()
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %%
# https://stackoverflow.com/questions/29838746/how-to-draw-subgraph-using-networkx
import networkx as nx
from matplotlib import pylab as pl

G = nx.karate_club_graph()
res = [0,1,2,3,4,5, 'parrot'] #I've added 'parrot', a node that's not in G
                              #just to demonstrate that G.subgraph is okay
                              #with nodes not in G.    
pos = nx.spring_layout(G)  #setting the positions with respect to G, not k.
k = G.subgraph(res)  

pl.figure()
nx.draw_networkx(k, pos=pos)

othersubgraph = G.subgraph(range(6,G.order()))
nx.draw_networkx(othersubgraph, pos=pos, node_color = 'b')
pl.show()
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %%
# https://stackoverflow.com/questions/29838746/how-to-draw-subgraph-using-networkx
import networkx as nx
from matplotlib import pylab as pl

# G = nx.karate_club_graph()

# res = [0,1,2,3,4,5, 'parrot'] #I've added 'parrot', a node that's not in G
                              #just to demonstrate that G.subgraph is okay
                              #with nodes not in G.    

G=nx.MultiDiGraph()  
# nx.spring_layout(G)
pos = nx.spring_layout(G)  #setting the positions with respect to G, not k.
k = G.subgraph(res)  

pl.figure()
nx.draw_networkx(k, pos=pos)

othersubgraph = G.subgraph(range(6,G.order()))
nx.draw_networkx(othersubgraph, pos=pos, node_color = 'b')
pl.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df0e0d73286b> in <module>()
#      12 # nx.spring_layout(G)
#      13 pos = nx.spring_layout(G)  #setting the positions with respect to G, not k.
# ---> 14 k = G.subgraph(res)
#      15
#      16 pl.figure()
#
# NameError: name 'res' is not defined

# %%
G = nx.karate_club_graph()
type(G)
# Out:
# networkx.classes.graph.Graph

# %%
# G=nx.MultiDiGraph()  
G = nx.karate_club_graph()
pl.figure()
nx.draw_networkx(G,with_labels=True)
pl.show()

# %%
# https://stackoverflow.com/questions/12894985/make-a-click-able-graph-by-networkx
import networkx as nx 
import matplotlib.pyplot as plt 
import pylab

class AnnoteFinder:  # thanks to http://www.scipy.org/Cookbook/Matplotlib/Interactive_Plotting
    """
    callback for matplotlib to visit a node (display an annotation) when points are clicked on.  The
    point which is closest to the click and within xtol and ytol is identified.
    """
    def __init__(self, xdata, ydata, annotes, axis=None, xtol=None, ytol=None):
        self.data = zip(xdata, ydata, annotes)
        if xtol is None: xtol = ((max(xdata) - min(xdata))/float(len(xdata)))/2
        if ytol is None: ytol = ((max(ydata) - min(ydata))/float(len(ydata)))/2
        self.xtol = xtol
        self.ytol = ytol
        if axis is None: axis = pylab.gca()
        self.axis= axis
        self.drawnAnnotations = {}
        self.links = []

    def __call__(self, event):
        if event.inaxes:
            clickX = event.xdata
            clickY = event.ydata
            if self.axis is None or self.axis==event.inaxes:
                annotes = []
                for x,y,a in self.data:
                    if  clickX-self.xtol < x < clickX+self.xtol and  clickY-self.ytol < y < clickY+self.ytol :
                        dx,dy=x-clickX,y-clickY
                        annotes.append((dx*dx+dy*dy,x,y, a) )
                if annotes:
                    annotes.sort() # to select the nearest node
                    distance, x, y, annote = annotes[0]
                    self.visitNode(annote)

    def visitNode(self, annote): # Visit the selected node
        # do something with the annote value
        print("visitNode", annote)

fig = plt.figure() 
ax = fig.add_subplot(111) 
ax.set_title('select nodes to navigate there')

# G=nx.MultiDiGraph()  # directed graph 
# G = nx.wheel_graph(5)
G = nx.karate_club_graph()

# pos=nx.spring_layout(G) # the layout gives us the nodes position x,y,annotes=[],[],[] for key in pos:
# d=pos[key]
# annotes.append(key)
# x.append(d[0])
# y.append(d[1]) 
# nx.draw(G,pos,font_size=8)

pos=nx.spring_layout(G) # the layout gives us the nodes position x,y,
annotes=[],[],[] 
for key in pos:
    d=pos[key]
    print(key)
    print(d)
#     annotes.append(key)
#     x.append(d[0])
#     y.append(d[1]) 
    nx.draw(G,pos,font_size=8)

af =  AnnoteFinder(x,y, annotes) 
fig.canvas.mpl_connect('button_press_event', af)

plt.show()
# Out:
# 0
# [ 0.28069438 -0.35870225]
# 1
# [ 0.23891261 -0.14358834]
# 2
# [-0.11042921 -0.06555593]
# 3
# [ 0.09242746 -0.3700358 ]
# 4
# [ 0.49982764 -0.68859225]
# 5
# [ 0.59292677 -0.83089454]
# 6
# [ 0.69230711 -0.72330771]
# 7
# [-0.00808605 -0.37661023]
# 8
# [ 0.02199464  0.1191428 ]
# 9
# [-0.42625988  0.07811761]
# 10
# [ 0.38615859 -0.81275435]
# 11
# [ 0.76471014 -0.41142432]
# 12
# [ 0.10261477 -0.68329346]
# 13
# [ 0.04354099 -0.08379954]
# 14
# [-0.02201898  0.73338214]
# 15
# [ 0.0649059   0.62300084]
# 16
# [ 0.88398269 -1.        ]
# 17
# [ 0.5713428  -0.15144708]
# 18
# [-0.35755891  0.69515243]
# 19
# [ 0.20497615  0.07097666]
# 20
# [-0.2742884   0.79816387]
# 21
# [ 0.53330647 -0.31887736]
# 22
# [-0.14783624  0.76198376]
# 23
# [-0.55493379  0.40210089]
# 24
# [-0.72961856 -0.01799077]
# 25
# [-0.75397579  0.16438195]
# 26
# [-0.59539445  0.74347704]
# 27
# [-0.50836458  0.17172053]
# 28
# [-0.38814192 -0.05178039]
# 29
# [-0.49779289  0.59255681]
# 30
# [ 0.09623754  0.2815079 ]
# 31
# [-0.29467681  0.03942709]
# 32
# [-0.17862793  0.44615434]
# 33
# [-0.22286226  0.36740769]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7a9e1cb0ee5e> in <module>()
#      65     nx.draw(G,pos,font_size=8)
#      66
# ---> 67 af =  AnnoteFinder(x,y, annotes)
#      68 fig.canvas.mpl_connect('button_press_event', af)
#      69
#
# NameError: name 'x' is not defined

# %%
pos
# Out:
# {}
